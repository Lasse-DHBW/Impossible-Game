# %% [markdown]
# This file demonstrates how to read the history pickles of a run

# %%
import torch
a = torch.load('runs/continuous_lunar_lander/20231219_212516/crossings_2.pt')
a[0]
# Out:
# {'parent1': <classes.NEAT.Genotype at 0x7f8ec1ebaf50>,
#  'parent2': <classes.NEAT.Genotype at 0x7f8ec1ebaf50>,
#  'offspring': <classes.NEAT.Genotype at 0x7f8ec41a0cd0>,
#  'offspring_before_mutation': <classes.NEAT.Genotype at 0x7f8ec41a2f90>}

# %%
b = torch.load('runs/continuous_lunar_lander/20231219_212516/fitness_perspecies_0.pt')
species = 0
fitnesses = 0
genotypes = 1
b[species][fitnesses][:5], b[species][genotypes][:5]
# Out:
# ([-893.1400498316254,
#   -367.5911577149185,
#   -131.46559974025257,
#   -148.72960279470686,
#   -471.768390777882],
# ...
#   <classes.NEAT.Genotype at 0x7f8ec1d8a7d0>])

# %%
a[0]['offspring'].uuid
# Out:
# '20231219212550481363_0e385732-a25a-41e9-bc46-e1c2b20662b9'

# %%
fitness = torch.load('runs/continuous_lunar_lander/2023_12_07_22_13_57_425933/fitness_perspecies_153.pt')
fitness
# Out:
# {0: [269.9597211164523,
#   -62.78927698722911,
#   27.89550653999662,
#   -426.98489194492083,
#   218.49694570184943,
#   234.10692854255905,
#   246.66049591371635,
#   -264.4201279415692,
#   -152.85711102566535,
#   -70.97294883400266,
#   233.28680153550218,
#   53.908457145363876,
#   214.7076970533987,
#   42.9710420413865,
#   12.082847012720519,
#   -25.981130606418322,
#   92.71239598103328,
#   -4.878711256079519,
#   -517.4040508125431,
#   -117.52427846298198,
#   -99.70380029995887,
#   -11.08397237037805,
#   279.16078812745513,
#   -85.69423663158005,
#   35.18016563287871,
#   104.22065265431218,
#   20.052192561327793,
#   199.7025582043547,
#   253.13582703427838,
#   -590.4024065016855,
#   168.69322536515432,
#   -74.5591721162989,
#   -57.95514902588174,
#   105.34617521284936,
#   266.6772825988811,
#   35.94920506933791,
#   92.97395982120133,
#   -128.70291547020588,
#   57.443976638795164,
#   265.84162532291265,
#   -424.77631792107724,
# ...
